# %%
import pandas as pd
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       1 import pandas as pd
# ----> 2 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /Users/hoseinzakariaee/miniforge3/lib/python3.9/site-packages (5.7.0)
# Collecting plotly
#   Downloading plotly-5.8.2-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: tenacity>=6.2.0 in /Users/hoseinzakariaee/miniforge3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.7.0
#     Uninstalling plotly-5.7.0:
#       Successfully uninstalled plotly-5.7.0
# Successfully installed plotly-5.8.2

# %%
df = pd.read_csv('BTC-USD.csv')
df = df[["Date", "Close"]]
df.columns = ["ds", "y"]
print(df)
# Out:
#               ds             y
# 0     2014-09-17    457.334015
# 1     2014-09-18    424.440002
# 2     2014-09-19    394.795990
# 3     2014-09-20    408.903992
# 4     2014-09-21    398.821014
# ...          ...           ...
# 2787  2022-05-05  36575.140625
# 2788  2022-05-06  36040.921875
# 2789  2022-05-07  35501.953125
# 2790  2022-05-08  34059.265625
# 2791  2022-05-09  31786.550781
#
# [2792 rows x 2 columns]

# %%
prophet = Prophet()
prophet.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /opt/homebrew/lib/python3.8/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -44.6087
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       5171.84    0.00957717       567.387      0.2779      0.2779      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       5184.58     0.0043024       270.803      0.1878           1      252
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       5202.03    0.00114849        167.46      0.5631      0.5631      370
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      343       5203.12     0.0029309       188.672    3.18e-05       0.001      461  LS failed, Hessian reset
#      399        5203.8    0.00666305       68.6166           1           1      533
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      402       5203.85   0.000944713       133.772   1.348e-05       0.001      578  LS failed, Hessian reset
#      499       5204.29   4.25966e-06        64.163           1           1      708
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      562       5204.32   5.31981e-06       63.4741   7.461e-08       0.001      823  LS failed, Hessian reset
#      571       5204.32   1.70622e-07       64.8131     0.06486           1      839
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future = prophet.make_future_dataframe(periods=100)
print(future)
# Out:
#              ds
# 0    2014-09-17
# 1    2014-09-18
# 2    2014-09-19
# 3    2014-09-20
# 4    2014-09-21
# ...         ...
# 2887 2022-08-13
# 2888 2022-08-14
# 2889 2022-08-15
# 2890 2022-08-16
# 2891 2022-08-17
#
# [2892 rows x 1 columns]

# %%
forecast = prophet.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(10)
# Out:
# /opt/homebrew/lib/python3.8/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /opt/homebrew/lib/python3.8/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds          yhat    yhat_lower    yhat_upper
# 2882 2022-08-08  59647.131531  51778.908002  67618.487019
# 2883 2022-08-09  59786.675630  52063.778182  67392.183447
# 2884 2022-08-10  59928.367937  52797.199329  67731.741142
# 2885 2022-08-11  59956.712258  51622.516443  67489.537578
# 2886 2022-08-12  60057.775863  51966.025603  68262.756044
# 2887 2022-08-13  60154.094475  52287.247368  68070.444210
# 2888 2022-08-14  60214.166113  52615.904795  68003.668451
# 2889 2022-08-15  60304.522712  52958.471086  68554.918004
# 2890 2022-08-16  60410.923593  52348.346404  67915.262560
# 2891 2022-08-17  60520.332800  52846.484429  68328.808799

# %%
from fbprophet.plot import plot
prophet.plot(forecast, figsize=(20, 10))
